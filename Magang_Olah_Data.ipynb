# %%
import pandas as pd
import numpy as np

# %%
glints_dokter = pd.read_csv("Magang_Glints_Kedokteran(dokter).csv")
glints_dokter.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  link  \
# 0      1726201819-1  https://glints.com/id/opportunities/jobs/explo...   NaN
# 1      1726201828-2  https://glints.com/id/opportunities/jobs/explo...   NaN
# 2      1726201830-3  https://glints.com/id/opportunities/jobs/explo...   NaN
# 3      1726201833-4  https://glints.com/id/opportunities/jobs/explo...   NaN
# 4      1726201837-5  https://glints.com/id/opportunities/jobs/explo...   NaN
#
#                                            link-href         Job Title  \
# 0  https://glints.com/id/opportunities/jobs/dokte...       Dokter Gigi
# 1  https://glints.com/id/opportunities/jobs/dokte...  Dokter Aesthetic
# 2  https://glints.com/id/opportunities/jobs/dokte...       Dokter Gigi
# 3  https://glints.com/id/opportunities/jobs/dokte...       Dokter Gigi
# 4  https://glints.com/id/opportunities/jobs/dokte...       Dokter Umum
#
#                       Company                           Time  \
# ...

# %%
glints_dokter.columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'link', 'link-href',
#        'Job Title', 'Company', 'Time', 'Persyaratan', 'Skill', 'Jobdesc',
#        'Alamat'],
#       dtype='object')

# %%
glints_dokter.drop(['link','web-scraper-order','web-scraper-start-url', 'link-href'], axis=1, inplace=True)

# %%
glints_dokter
# Out:
#                                             Job Title  \
# 0                                         Dokter Gigi
# 1                                    Dokter Aesthetic
# 2                                         Dokter Gigi
# 3                                         Dokter Gigi
# 4                                         Dokter Umum
# ..                                                ...
# 85                                             Dokter
# 86                                             Dokter
# 87                                    Dokter Estetika
# 88  Dokter Kecantikan / Aesthetic doctor / dokter ...
# 89       Dokter Estetika / Dokter Kecantikan / Doctor
#
#                             Company                           Time  \
# 0                      JH AESTHETIC  Penuh Waktu · Kerja di kantor
# 1                     CV PELANGI UV  Penuh Waktu · Kerja di kantor
# 2                   Bia Dental Care  Penuh Waktu · Kerja di kantor
# ...
